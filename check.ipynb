# %%
import numpy as np

# %%
X = np.load('attack_X.npy')
y = np.load('attack_y.npy')

# %%
X.shape
# Out:
# (30000, 5)

# %%
y.shape
# Out:
# (30000,)

# %%
X_nonmember = X[y == 0]

# %%
X_member = X[y == 1]

# %%
X_member.mean(axis=0)
# Out:
# array([ 10.37051658,   4.27607574,   3.41298259, 149.181     ,
#          0.60098787])

# %%
X_nonmember.mean(axis=0)
# Out:
# array([ 10.37624336,   4.29137544,   3.42094891, 149.22253333,
#          0.60029063])
